# %% [markdown]
# # 🗂️ Python Syntax – Core Rules & Examples

# %%
# 🔹 Quick Tips:
# - Indentation defines code blocks
# - Python is case-sensitive
# - No semicolons needed
# - Use # for comments
# - Keep code clean & readable

# %%
# 1️⃣ Indentation (VERY IMPORTANT) 📐
if True:
    print("Python uses indentation")
# print("Error")   # ❌ IndentationError
# Out:
# Python uses indentation

# %%
# 2️⃣ Comments 📝
# This is a single-line comment

"""
This is a
multi-line comment (docstring style)
"""
# Out:
# '\nThis is a\nmulti-line comment (docstring style)\n'

# %%
# 3️⃣ Variables & Assignment 🧩
x = 10
name = "Python"
price = 99.99

# %%
# 4️⃣ Case Sensitivity 🔠
age = 20
Age = 30
print(age, Age)   # Different variables
# Out:
# 20 30

# %%
# 5️⃣ Print Statement 🖨️
print("Hello, World!")
print("Value of x:", x)
# Out:
# Hello, World!
# Value of x: 10

# %%
# 6️⃣ Input Statement ⌨️
# user_name = input("Enter your name: ")

# %%
# 7️⃣ Data Types 🔢📝
a = 5          # int
b = 3.14       # float
c = "Hi"       # str
d = True       # bool

# %%
# 8️⃣ Statements & Expressions ⚙️
result = a + b * 2
print(result)
# Out:
# 11.280000000000001

# %%
# 9️⃣ Multiple Assignment 🎯
x, y, z = 1, 2, 3
print(x, y, z)
# Out:
# 1 2 3

# %%
# 🔟 Line Continuation ↩️
total = (1 + 2 + 3 +
         4 + 5)
print(total)
# Out:
# 15
