# %% [markdown]
# # 🗂️ Main Data Collection Tools 🛠️

# %%
# 1️⃣ Definition
definition = """
Data Collection Tools are software, platforms, or frameworks used to gather, 
store, and organize data efficiently from primary or secondary sources.
"""
print(definition)
# Out:
# Data Collection Tools are software, platforms, or frameworks used to gather,
# store, and organize data efficiently from primary or secondary sources.

# %%
# 2️⃣ Primary Data Collection Tools 🧩
primary_tools = {
    "Google Forms / Microsoft Forms": "Create surveys and collect responses online",
    "SurveyMonkey / Typeform": "Professional survey platforms with analytics",
    "Interview Recording Tools": "Zoom, Skype, or voice recorders to capture interviews",
    "Observation Tools": "CCTV, IoT sensors, manual checklists for behavior tracking",
    "Experiment Tools": "Lab equipment, sensors, simulation software for controlled tests"
}

print("Primary Data Collection Tools:")
for tool, desc in primary_tools.items():
    print(f"- {tool}: {desc}")
# Out:
# Primary Data Collection Tools:
# - Google Forms / Microsoft Forms: Create surveys and collect responses online
# - SurveyMonkey / Typeform: Professional survey platforms with analytics
# - Interview Recording Tools: Zoom, Skype, or voice recorders to capture interviews
# - Observation Tools: CCTV, IoT sensors, manual checklists for behavior tracking
# - Experiment Tools: Lab equipment, sensors, simulation software for controlled tests

# %%
# 3️⃣ Secondary Data Collection Tools 📚
secondary_tools = {
    "Kaggle": "Repository of datasets for ML and data analysis",
    "UCI Machine Learning Repository": "Classic datasets for research",
    "Government Portals": "Open data portals like data.gov for official statistics",
    "APIs": "Twitter API, Facebook Graph API, weather APIs for real-time data",
    "Web Scraping Tools": "BeautifulSoup, Scrapy, Selenium to extract data from websites"
}

print("\nSecondary Data Collection Tools:")
for tool, desc in secondary_tools.items():
    print(f"- {tool}: {desc}")
# Out:
# Secondary Data Collection Tools:
# - Kaggle: Repository of datasets for ML and data analysis
# - UCI Machine Learning Repository: Classic datasets for research
# - Government Portals: Open data portals like data.gov for official statistics
# - APIs: Twitter API, Facebook Graph API, weather APIs for real-time data
# - Web Scraping Tools: BeautifulSoup, Scrapy, Selenium to extract data from websites

# %%
# 4️⃣ Quick Tips 🔹
# - Choose tools based on your data type and source
# - Ensure reliability and legal compliance
# - For surveys, ensure user-friendly design
# - For scraping/API, respect robots.txt and rate limits
# - Always document data source and collection method

# %%
# 5️⃣ Example: Collecting data from an API
import requests

# Example: Fetch exchange rates (public API)
# response = requests.get("https://api.exchangerate-api.com/v4/latest/USD")
# data = response.json()
# print(data)   # This is secondary data collected programmatically
