# %% [markdown]
# # 🗂️ Setting the Context – Understanding the Problem 🔍

# %%
# 1️⃣ Understand the Problem 🧠
# Before coding or modeling, answer:
# - What is the objective?
# - What data is available?
# - What outcome do we want?

project_name = "Titanic Survival Prediction"
objective = "Predict whether a passenger survives based on features"
data_source = "Kaggle Titanic Dataset"

print(f"Project: {project_name}")
print(f"Objective: {objective}")
print(f"Data Source: {data_source}")

# %%
# 2️⃣ Know Your Data 📊
import pandas as pd

df = pd.read_csv("titanic.csv")   # Load dataset
print(df.head())                  # Check first rows
print(df.info())                  # Check data types & missing values
print(df.describe())              # Statistical overview

# %%
# 3️⃣ Ask Key Questions ❓
# Example:
# - How many passengers survived?
# - Which features are important? (Age, Sex, Class, etc.)
# - Are there missing values?

# %%
# 4️⃣ Set Goals & Scope 🎯
goals = [
    "Perform data cleaning & EDA",
    "Feature engineering",
    "Build ML models",
    "Evaluate & select best model",
    "Deploy solution"
]

for idx, goal in enumerate(goals, 1):
    print(f"{idx}. {goal}")
# Out:
# 1. Perform data cleaning & EDA
# 2. Feature engineering
# 3. Build ML models
# 4. Evaluate & select best model
# 5. Deploy solution

# %%
# 5️⃣ Quick Tips 🔹
# - Always understand business / domain context first
# - Explore data before modeling
# - Define success criteria clearly
# - Make assumptions explicit
# - Document your findings for reproducibility
