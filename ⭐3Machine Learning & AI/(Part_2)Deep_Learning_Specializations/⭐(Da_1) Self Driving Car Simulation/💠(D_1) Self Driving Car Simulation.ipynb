# %% [markdown]
# model.py

# %%
data_df = pd.read_csv(
    os.path.join(args.data_dir, 'driving_log.csv'),
    names=['center', 'left', 'right', 'steering', 'throttle', 'reverse', 'speed']
)

# %% [markdown]
# utils.py

# %%
mask[np.where(
    (ym - y1) * (x2 - x1) - (y2 - y1) * (xm - x1) > 0
)] = 1

# %% [markdown]
# ⭐ Optional Pro Improvement (Cleaner & Faster)

# %%
condition = (ym - y1) * (x2 - x1) - (y2 - y1) * (xm - x1) > 0
mask[condition] = 1
