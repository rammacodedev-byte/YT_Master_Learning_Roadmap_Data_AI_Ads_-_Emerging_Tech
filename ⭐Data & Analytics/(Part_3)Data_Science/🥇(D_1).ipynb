# %% [markdown]
# Data

# %%
# 📚 Q&A about Data
question = "What is data? 🤔"
answer = "Data is a collection of facts, statistics, or information used for analysis. 📊"
example = "Example: Customer ages, sales numbers, or website visits. 🛒💻"

print(f"Q: {question}\nA: {answer}\n💡 {example}")
# Out:
# ❓ What is data?
# 💡 Example: Numbers, text, images, etc.

# %% [markdown]
# Data In Data Science

# %%
# 📊 Data Science Q&A
question = "What is data in Data Science? 🤔"
answer = "Data in Data Science refers to raw information collected from various sources to extract insights and make decisions. 🧠💡"
example = "Example: Sensor readings, social media posts, sales records. 🌐📈🛒"

print(f"Q: {question}\nA: {answer}\n💡 {example}")
# Out:
# Q: What is data in Data Science? 🤔
# A: Data in Data Science refers to raw information collected from various sources to extract insights and make decisions. 🧠💡
# 💡 Example: Sensor readings, social media posts, sales records. 🌐📈🛒

# %% [markdown]
# Science

# %%
# 🔬 Science Q&A
question = "What is Science? 🤔"
answer = "Science is the systematic study of the natural and physical world through observation and experimentation. 🧪🌍"
example = "Example: Physics laws, chemical reactions, or biological studies. ⚛️🧬🔭"

print(f"Q: {question}\nA: {answer}\n💡 {example}")
# Out:
# Q: What is Science? 🤔
# A: Science is the systematic study of the natural and physical world through observation and experimentation. 🧪🌍
# 💡 Example: Physics laws, chemical reactions, or biological studies. ⚛️🧬🔭

# %% [markdown]
# Who is Data Scientist

# %%
# 👩‍💻 Data Science Q&A
question = "Who is a Data Scientist? 🤔"
answer = "A Data Scientist is a professional who collects, analyzes, and interprets complex data to help make informed decisions. 📊🧠"
example = "Example: Predicting customer behavior, analyzing trends, building AI models. 🤖📈💡"

print(f"Q: {question}\nA: {answer}\n💡 {example}")

# %% [markdown]
# Career Paths | Data Science

# %%
# 🧑‍💻 Data Science Career Paths Table
career_paths = ["Data Analyst 📊", "Data Scientist 🤖", "ML Engineer ⚙️", "Data Engineer 🏗️"]
tools = ["Excel, SQL, Tableau 🛠️", "Python, R, ML Libraries 🧩", "Python, TensorFlow, PyTorch ⚡", "SQL, Spark, Airflow 🔧"]
requirements = [
    "Statistics, Data Cleaning, Visualization 📈",
    "Math, Programming, ML, Problem Solving 🧠",
    "ML, Deep Learning, Deployment 🚀",
    "ETL, Big Data, Pipeline Architecture 🏗️"
]

print("🔹 Data Science Career Paths, Tools & Requirements 🔹\n")
print(f"{'Career Path':<20} | {'Tools':<30} | {'Requirements'}")
print("-"*90)
for i in range(len(career_paths)):
    print(f"{career_paths[i]:<20} | {tools[i]:<30} | {requirements[i]}")
# Out:
# 🔹 Data Science Career Paths, Tools & Requirements 🔹
#
# Career Path          | Tools                          | Requirements
# ------------------------------------------------------------------------------------------
# Data Analyst 📊       | Excel, SQL, Tableau 🛠️         | Statistics, Data Cleaning, Visualization 📈
# Data Scientist 🤖     | Python, R, ML Libraries 🧩      | Math, Programming, ML, Problem Solving 🧠
# ML Engineer ⚙️       | Python, TensorFlow, PyTorch ⚡  | ML, Deep Learning, Deployment 🚀
# Data Engineer 🏗️     | SQL, Spark, Airflow 🔧          | ETL, Big Data, Pipeline Architecture 🏗️
